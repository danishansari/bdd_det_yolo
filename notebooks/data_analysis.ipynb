# %% [markdown]
# ## Detection (Yolov5) on BDD-100k-Dataset
#
# BDD-100k-dataset on various task of detection, segmentation Pose estimation, lane marking etc.
# In this experiment we're only interested in the detection task with following classes.
#   * 0: person
#   * 1: rider
#   * 2: car
#   * 3: bus
#   * 4: truck
#   * 5: bike
#   * 6: motor
#   * 7: train
#   * 8: traffic sign
#   * 9: traffic light

# %% [markdown]
# ## Datset exploration and analysis

# %% [markdown]
# ### 1. Data distibution - train/eval sample split

# %%
from PIL import Image
from matplotlib import pyplot as plt

im = Image.open("../plots/train_val_dist.png")
plt.axis("off")
plt.imshow(im)

# %% [markdown]
# From above graph we can observe that train-val ratio is 1/7, about 14%. Which is ok in terms of train-val split in most experiments, having a 20% split is considered ideal.

# %% [markdown]
# ### 2. Classwise Data distribution

# %%
from PIL import Image
from matplotlib import pyplot as plt

im1 = Image.open("../plots/training_class_dist.png")
im2 = Image.open("../plots/eval_class_dist.png")

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 8))
axes[0].set_axis_off()
axes[0].imshow(im1)
axes[1].set_axis_off()
axes[1].imshow(im2)

# %% [markdown]
# From above plot its evident that there is huge imbalance in the dataset, `car` being the majority and objects like `rider`, `bus`, `motor`, `bike`, `truck` are very less with `train` being the least of all samples.

# %% [markdown]
# ### 3. Objects width and height distribution

# %%
from PIL import Image
from matplotlib import pyplot as plt

im = Image.open("../plots/training_size_dist.png")
plt.axis("off")
plt.imshow(im)

# %% [markdown]
# From above plot we can see most of the object sizes are in the middle of the plor around `700x300` dimension.

# %% [markdown]
# ### 4. Area Vs no of samples in the dataset

# %%
from PIL import Image
from matplotlib import pyplot as plt

im = Image.open("../plots/object_size_dist.png")
plt.axis("off")
plt.imshow(im)

# %% [markdown]
# From this plot its evident that the majority are also bigger objects and minority classes are smaller objects. Which is goin to make it even harder to detect.

# %% [markdown]
# ### 5. Atrribute samples distribution
# * Occuluded
# * Truncated

# %%
from PIL import Image
from matplotlib import pyplot as plt

im = Image.open("../plots/object_attr_dist.png")
plt.axis("off")
plt.imshow(im)

# %% [markdown]
# ### Some Image Vizualization
#
# 1. A few far away traffic-signs are visible but not annotated.

# %%
from PIL import Image
from matplotlib import pyplot as plt

im = Image.open("../plots/images/c776d10b-6732b55c_anns.jpg")
plt.axis("off")
plt.imshow(im)

# %% [markdown]
# 2.  Poster on building is marked as traffic-sign

# %%
from PIL import Image
from matplotlib import pyplot as plt

im = Image.open("../plots/images/c9ca4c6c-4c9db372_anns.jpg")
plt.axis("off")
plt.imshow(im)

# %% [markdown]
# 3. School bus annotated as a truck in right corner

# %%
from PIL import Image
from matplotlib import pyplot as plt

im = Image.open("../plots/images/c7331983-36418bf8_anns.jpg")
plt.axis("off")
plt.imshow(im)

# %% [markdown]
# ### Anamolies in annotations
# Though the dataset is huge and mostly correct annotated, there a few anamolies present.
# * Some class labels are wrong
# * Some object are missed out.
# * Sometime traffic sign are marked on walls.
# * Huge imbalance accross classes, data for `train-class` is almost `nil`.
#
# ### Conclusion
#
# * Dataset split train-to-val is 1:7.
# * Data is highly imabalanced - there is a few to no samples for half of the classes.
# * Bigger objects are in large numbers which smaller objects are in minority samples.
